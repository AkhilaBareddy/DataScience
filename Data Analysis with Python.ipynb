# %%
import numpy as np
import pandas as pd

# %%
a=10
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
path='D:\DA with Python\Cereal.csv'

# %%
path
# Out:
# 'D:\\DA with Python\\Cereal.csv'

# %%
df=pd.read_csv(path)

# %%
df.head(5)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C      70.0      4.0  1.0   130.0   10.0
# 1          100% Natural Bran   Q    C     120.0      3.0  5.0    15.0    2.0
# 2                   All-Bran   K    C      70.0      4.0  1.0   260.0    9.0
# 3  All-Bran with Extra Fiber   K    C      50.0      4.0  0.0   140.0   14.0
# 4             Almond Delight   R    C     110.0      2.0  2.0   200.0    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0      25.0    3.0     1.0  0.33  68.402973
# 1    8.0     8.0   135.0       0.0    3.0     1.0  1.00  33.983679
# 2    7.0     5.0   320.0      25.0    3.0     1.0  0.33  59.425505
# 3    8.0     0.0   330.0      25.0    3.0     1.0  0.50  93.704912
# 4   14.0     8.0    -1.0      25.0    3.0     1.0  0.75  34.384843

# %%
df.tail(5)
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C     110.0      2.0  1.0   250.0    0.0
# 73                 Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 74           Wheat Chex   R    C     100.0      3.0  1.0   230.0    3.0
# 75             Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 76  Wheaties Honey Gold   G    C     110.0      2.0  1.0   200.0    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0     3.0    60.0      25.0    3.0     1.0  0.75  39.106174
# 73   13.0    12.0    25.0      25.0    2.0     1.0  1.00  27.753301
# 74   17.0     3.0   115.0      25.0    1.0     1.0  0.67  49.787445
# 75   17.0     3.0   110.0      25.0    1.0     1.0  1.00  51.592193
# 76   16.0     8.0    60.0      25.0    1.0     1.0  0.75  36.187559

# %%
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories    float64
# protein     float64
# fat         float64
# sodium      float64
# fiber       float64
# carbo       float64
# sugars      float64
# potass      float64
# vitamins    float64
# shelf       float64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
df.describe(include="all")
# Out:
#                   name  mfr type    calories    protein        fat  \
# count               77   74   74   74.000000  74.000000  74.000000
# unique              76    7    2         NaN        NaN        NaN
# top     Muesli Raisins    K    C         NaN        NaN        NaN
# freq                 2   23   71         NaN        NaN        NaN
# mean               NaN  NaN  NaN  105.540541   2.500000   0.945946
# std                NaN  NaN  NaN   18.442201   1.088546   0.963610
# min                NaN  NaN  NaN   50.000000   1.000000   0.000000
# 25%                NaN  NaN  NaN  100.000000   2.000000   0.000000
# 50%                NaN  NaN  NaN  110.000000   2.000000   1.000000
# 75%                NaN  NaN  NaN  110.000000   3.000000   1.000000
# max                NaN  NaN  NaN  160.000000   6.000000   5.000000
#
#             sodium      fiber      carbo     sugars      potass    vitamins  \
# count    74.000000  74.000000  74.000000  74.000000   74.000000   74.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
# name        77 non-null object
# mfr         74 non-null object
# type        74 non-null object
# calories    74 non-null float64
# protein     74 non-null float64
# fat         74 non-null float64
# sodium      74 non-null float64
# fiber       74 non-null float64
# carbo       74 non-null float64
# sugars      74 non-null float64
# potass      74 non-null float64
# vitamins    74 non-null float64
# shelf       74 non-null float64
# weight      74 non-null float64
# cups        74 non-null float64
# rating      74 non-null float64
# dtypes: float64(13), object(3)
# memory usage: 9.8+ KB

# %%
df['rating']=df['rating'].astype(float)

# %%
df['rating'].dtype
# Out:
# dtype('float64')

# %%
#Simple Featire Scaling

# %%
df['calories']=df['calories']/df['calories'].max()

# %%
df['calories']
# Out:
# 0     0.4375
# 1     0.7500
# 2     0.4375
# 3     0.3125
# 4     0.6875
#        ...
# 72    0.6875
# 73    0.6875
# 74    0.6250
# 75    0.6250
# 76    0.6875
# Name: calories, Length: 77, dtype: float64

# %%
#Z-score

# %%
df['calories']=(df['calories']-df['calories'].mean())/df['calories'].std()

# %%
df['calories']
# Out:
# 0    -1.927131
# 1     0.784042
# 2    -1.927131
# 3    -3.011600
# 4     0.241807
#         ...
# 72    0.241807
# 73    0.241807
# 74   -0.300427
# 75   -0.300427
# 76    0.241807
# Name: calories, Length: 77, dtype: float64

# %%
#Binning

# %%
bins=np.linspace(min(df['calories']),max(df['calories']),4)
group_names=['low','medium','high']
df['calories-binned']=pd.cut(df['calories'],bins,labels=group_names,include_lowest=True)

# %%
df['calories-binned']
# Out:
# 0        low
# 1     medium
# 2        low
# 3        low
# 4     medium
#        ...
# 72    medium
# 73    medium
# 74    medium
# 75    medium
# 76    medium
# Name: calories-binned, Length: 77, dtype: category
# Categories (3, object): [low < medium < high]

# %%
#Converting categorical var to dummy var

# %%
pd.get_dummies(df['calories-binned'])
# Out:
# calories-binned  low  medium  high
# 0                  1       0     0
# 1                  0       1     0
# 2                  1       0     0
# 3                  1       0     0
# 4                  0       1     0
# ..               ...     ...   ...
# 72                 0       1     0
# 73                 0       1     0
# 74                 0       1     0
# 75                 0       1     0
# 76                 0       1     0
#
# [77 rows x 3 columns]

# %%
import pandas as pd
df=pd.DataFrame({'A':[2,3,5], 'B':[4,6,10]})
print(df.set_index('A').columnsumns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-c34e80ea3201> in <module>
#       1 import pandas as pd
#       2 df=pd.DataFrame({'A':[2,3,5], 'B':[4,6,10]})
# ----> 3 print(df.set_index('A').columnsumns)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'columnsumns'

# %%
import numpy as np
a=np.array([5,7,3,1])
b=np.array([90,50,0])
c=a*b
print(c)

# %%
a=True
b=False
c=False
if not a or b:
    print("COrrect Answer")
elif not a or not b and c:
    print('Maybe correct ans')
elif not a or b or not b and a:
    print('maybe worng answer')
else:
    print('wrong ans')
