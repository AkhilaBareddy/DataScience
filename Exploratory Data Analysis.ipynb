# %%
#Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %%
path= "D:\DA with Python\cereal.csv"

# %%
path
df=pd.read_csv(path)

# %%
#display all the cells in data frame
pd.options.display.max_rows=999

# %%
df.head(5)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C      70.0      4.0  1.0   130.0   10.0
# 1          100% Natural Bran   Q    C     120.0      3.0  5.0    15.0    2.0
# 2                   All-Bran   K    C      70.0      4.0  1.0   260.0    9.0
# 3  All-Bran with Extra Fiber   K    C      50.0      4.0  0.0   140.0   14.0
# 4             Almond Delight   R    C     110.0      2.0  2.0   200.0    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0      25.0    3.0     1.0  0.33  68.402973
# 1    8.0     8.0   135.0       0.0    3.0     1.0  1.00  33.983679
# 2    7.0     5.0   320.0      25.0    3.0     1.0  0.33  59.425505
# 3    8.0     0.0   330.0      25.0    3.0     1.0  0.50  93.704912
# 4   14.0     8.0    -1.0      25.0    3.0     1.0  0.75  34.384843

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C     110.0      2.0  1.0   250.0    0.0
# 73                 Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 74           Wheat Chex   R    C     100.0      3.0  1.0   230.0    3.0
# 75             Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 76  Wheaties Honey Gold   G    C     110.0      2.0  1.0   200.0    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0     3.0    60.0      25.0    3.0     1.0  0.75  39.106174
# 73   13.0    12.0    25.0      25.0    2.0     1.0  1.00  27.753301
# 74   17.0     3.0   115.0      25.0    1.0     1.0  0.67  49.787445
# 75   17.0     3.0   110.0      25.0    1.0     1.0  1.00  51.592193
# 76   16.0     8.0    60.0      25.0    1.0     1.0  0.75  36.187559

# %%
x=df['name']
y=df['calories']

# %%
x
y
# Out:
# 0      70.0
# 1     120.0
# 2      70.0
# 3      50.0
# 4     110.0
# 5     110.0
# 6     110.0
# 7     130.0
# 8      90.0
# 9      90.0
# 10    120.0
# 11    110.0
# 12    120.0
# 13    110.0
# 14    110.0
# 15    110.0
# 16    100.0
# 17    110.0
# 18    110.0
# 19    110.0
# 20    100.0
# 21    110.0
# 22    100.0
# 23    100.0
# 24    110.0
# 25    110.0
# 26    100.0
# 27      NaN
# 28    120.0
# 29    110.0
# 30    100.0
# 31    110.0
# 32    100.0
# 33    110.0
# 34    120.0
# 35    120.0
# 36    110.0
# 37    110.0
# 38    110.0
# 39    140.0
# 40    110.0
# 41    100.0
# 42    110.0
# 43    100.0
# 44      NaN
# 45      NaN
# 46    160.0
# 47    100.0
# 48    120.0
# 49    140.0
# 50     90.0
# 51    130.0
# 52    120.0
# 53    100.0
# 54     50.0
# 55     50.0
# 56    100.0
# 57    100.0
# 58    120.0
# 59    100.0
# 60     90.0
# 61    110.0
# 62    110.0
# 63     80.0
# 64     90.0
# 65     90.0
# 66    110.0
# 67    110.0
# 68     90.0
# 69    110.0
# 70    140.0
# ...

# %%
plt.scatter(x,y)

# %%
cal_count=df['calories'].value_counts

# %%
cal_count
# Out:
# <bound method IndexOpsMixin.value_counts of 0      70.0
# 1     120.0
# 2      70.0
# 3      50.0
# 4     110.0
# 5     110.0
# 6     110.0
# 7     130.0
# 8      90.0
# 9      90.0
# 10    120.0
# 11    110.0
# 12    120.0
# 13    110.0
# 14    110.0
# 15    110.0
# 16    100.0
# 17    110.0
# 18    110.0
# 19    110.0
# 20    100.0
# 21    110.0
# 22    100.0
# 23    100.0
# 24    110.0
# 25    110.0
# 26    100.0
# 27      NaN
# 28    120.0
# 29    110.0
# 30    100.0
# 31    110.0
# 32    100.0
# 33    110.0
# 34    120.0
# 35    120.0
# 36    110.0
# 37    110.0
# 38    110.0
# 39    140.0
# 40    110.0
# 41    100.0
# 42    110.0
# 43    100.0
# 44      NaN
# 45      NaN
# 46    160.0
# 47    100.0
# 48    120.0
# 49    140.0
# 50     90.0
# 51    130.0
# 52    120.0
# 53    100.0
# 54     50.0
# 55     50.0
# 56    100.0
# 57    100.0
# 58    120.0
# 59    100.0
# 60     90.0
# 61    110.0
# 62    110.0
# 63     80.0
# 64     90.0
# 65     90.0
# 66    110.0
# 67    110.0
# ...

# %%
df_test=df[['calories', 'name', 'protein']]

# %%
df_test
# Out:
#     calories                         name  protein
# 0       70.0                    100% Bran      4.0
# 1      120.0            100% Natural Bran      3.0
# 2       70.0                     All-Bran      4.0
# 3       50.0    All-Bran with Extra Fiber      4.0
# 4      110.0               Almond Delight      2.0
# 5      110.0      Apple Cinnamon Cheerios      2.0
# 6      110.0                  Apple Jacks      2.0
# 7      130.0                      Basic 4      3.0
# 8       90.0                    Bran Chex      2.0
# 9       90.0                  Bran Flakes      3.0
# 10     120.0                 Cap'n'Crunch      1.0
# 11     110.0                     Cheerios      6.0
# 12     120.0        Cinnamon Toast Crunch      1.0
# 13     110.0                     Clusters      3.0
# 14     110.0                  Cocoa Puffs      1.0
# 15     110.0                    Corn Chex      2.0
# 16     100.0                  Corn Flakes      2.0
# ...

# %%
df_grp=df_test.groupby(['name'], as_index=False).mean()

# %%
df_grp
# Out:
#                            name  calories  protein
# 0                     100% Bran      70.0      4.0
# 1             100% Natural Bran     120.0      3.0
# 2                      All-Bran      70.0      4.0
# 3     All-Bran with Extra Fiber      50.0      4.0
# 4                Almond Delight     110.0      2.0
# 5       Apple Cinnamon Cheerios     110.0      2.0
# 6                   Apple Jacks     110.0      2.0
# 7                       Basic 4     130.0      3.0
# 8                     Bran Chex      90.0      2.0
# 9                   Bran Flakes      90.0      3.0
# 10                 Cap'n'Crunch     120.0      1.0
# 11                     Cheerios     110.0      6.0
# 12        Cinnamon Toast Crunch     120.0      1.0
# 13                     Clusters     110.0      3.0
# 14                  Cocoa Puffs     110.0      1.0
# 15                    Corn Chex     110.0      2.0
# 16                  Corn Flakes     100.0      2.0
# ...

# %%
df_pivot=df_grp.pivot_table(index='calories', columns='name')
df_pivot
# Out:
#            protein                                                       \
# name     100% Bran 100% Natural Bran All-Bran All-Bran with Extra Fiber
# calories
# 50.0           NaN               NaN      NaN                       4.0
# 70.0           4.0               NaN      4.0                       NaN
# 80.0           NaN               NaN      NaN                       NaN
# 90.0           NaN               NaN      NaN                       NaN
# 100.0          NaN               NaN      NaN                       NaN
# 110.0          NaN               NaN      NaN                       NaN
# 120.0          NaN               3.0      NaN                       NaN
# 130.0          NaN               NaN      NaN                       NaN
# 140.0          NaN               NaN      NaN                       NaN
# 160.0          NaN               NaN      NaN                       NaN
#
#                                                                                \
# ...

# %%
#Heat Map

# %%
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar() #---- #to show the bar of color
plt.show() #-----#to remove extra info

# %%
#Correlation--- measures to what extent different variables are interdependent
#like rain and umbrella

# %%
import seaborn as sns

# %%
sns.regplot(x='protein', y='calories', data=df)
plt.ylim(0,)
plt.show()

#weak correlation

# %%
sns.regplot(x='fat', y='calories', data=df)
plt.ylim(0,)
#positive correlation-- with the increase in value of fat, calories also increases.
# Out:
# (0, 168.74250281597978)

# %%
sns.regplot(x='fiber', y='calories', data=df)
plt.ylim(0,)
#negative correlation--- as the fibre value increase, calories value decreases
# Out:
# (0, 165.676192127558)

# %%
#Pearson Correlation
#Strength of teh correlation between two features
#Correlation co-efficient 
#P-value

# %%
#Correlation coefficient
#close to +1----- large positive relationship
#close to -1----- large negative relationship
#cloe to 0------- No relationship

#P-Value
#p-value < 0.0001 ---- strong certainity in the result
#p-value < 0.05 ------ moderate certainity
#p-value < 0.1-------- weak certainity
#p-value > 0.1-------- No certainity

# %%
df
pd.options.display.max_rows=999

# %%
df
# Out:
#                            name  mfr type  calories  protein  fat  sodium  \
# 0                     100% Bran    N    C      70.0      4.0  1.0   130.0
# 1             100% Natural Bran    Q    C     120.0      3.0  5.0    15.0
# 2                      All-Bran    K    C      70.0      4.0  1.0   260.0
# 3     All-Bran with Extra Fiber    K    C      50.0      4.0  0.0   140.0
# 4                Almond Delight    R    C     110.0      2.0  2.0   200.0
# 5       Apple Cinnamon Cheerios    G    C     110.0      2.0  2.0   180.0
# 6                   Apple Jacks    K    C     110.0      2.0  0.0   125.0
# 7                       Basic 4    G    C     130.0      3.0  2.0   210.0
# 8                     Bran Chex    R    C      90.0      2.0  1.0   200.0
# 9                   Bran Flakes    P    C      90.0      3.0  0.0   210.0
# 10                 Cap'n'Crunch    Q    C     120.0      1.0  2.0   220.0
# 11                     Cheerios    G    C     110.0      6.0  2.0   290.0
# ...

# %%
df['calories']=df['calories'].fillna(0)
df['fat']=df['fat'].fillna(0)

# %%
df['calories']
df['fat']
# Out:
# 0     1.0
# 1     5.0
# 2     1.0
# 3     0.0
# 4     2.0
# 5     2.0
# 6     0.0
# 7     2.0
# 8     1.0
# 9     0.0
# 10    2.0
# 11    2.0
# 12    3.0
# 13    2.0
# 14    1.0
# 15    0.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    3.0
# 20    0.0
# 21    0.0
# 22    1.0
# 23    0.0
# 24    1.0
# 25    0.0
# 26    0.0
# 27    0.0
# 28    0.0
# 29    1.0
# 30    0.0
# 31    1.0
# 32    1.0
# 33    0.0
# 34    3.0
# 35    2.0
# 36    1.0
# 37    0.0
# 38    1.0
# 39    1.0
# 40    1.0
# 41    2.0
# 42    1.0
# 43    1.0
# 44    0.0
# 45    0.0
# 46    2.0
# 47    1.0
# 48    1.0
# 49    2.0
# 50    0.0
# 51    2.0
# 52    1.0
# 53    0.0
# 54    0.0
# 55    0.0
# 56    1.0
# 57    2.0
# 58    1.0
# 59    2.0
# 60    0.0
# 61    0.0
# 62    0.0
# 63    0.0
# 64    0.0
# 65    0.0
# 66    1.0
# 67    0.0
# 68    0.0
# 69    1.0
# 70    1.0
# 71    1.0
# 72    1.0
# 73    1.0
# 74    1.0
# 75    1.0
# 76    1.0
# Name: fat, dtype: float64

# %%
pearson_coef= stats.pearsonr(df['fat'], df['calories'])

# %%
pearson_coef
# Out:
# (0.41964835121610766, 0.00014520237178903197)

# %%
#Anova(Analysis of Variance)--- statistical comparision of groups
#finding correlation between diff grps of categorical variables
#F-test score-- variation between sample group means divided by variation within sample group
#p-value--confidence degree

# %%
df_anova=df[['calories', 'fat']]
grouped_anova=df_anova.groupby(['calories'])
grouped_anova

# %%
anova_res1=stats.f_oneway(df['calories'], df['sodium'].fillna(0))
anova_res1
# Out:
# F_onewayResult(statistic=24.851278485264558, pvalue=1.6691874287674281e-06)

# %%
df[['calories','fat']].corr()
# Out:
#           calories       fat
# calories  1.000000  0.419648
# fat       0.419648  1.000000

# %%
sns.boxplot(x='type', y='fat', data=df)

# %%
df['fat'].value_counts().to_frame()
# Out:
#      fat
# 0.0   30
# 1.0   30
# 2.0   13
# 3.0    3
# 5.0    1

# %%
#rename
fat_count=df['fat'].value_counts().to_frame()
fat_count.rename(columns={'fat':'value_counts'}, inplace=True)
fat_count
# Out:
#      value_counts
# 0.0            30
# 1.0            30
# 2.0            13
# 3.0             3
# 5.0             1

# %%
cal_counts=df['calories'].value_counts().to_frame()
cal_counts.rename(columns={'calories':'value_counts'}, inplace=True)
cal_counts.index.name='calories'
cal_counts
# Out:
#           value_counts
# calories
# 110.0               29
# 100.0               17
# 120.0                9
# 90.0                 7
# 140.0                3
# 0.0                  3
# 50.0                 3
# 130.0                2
# 70.0                 2
# 80.0                 1
# 160.0                1

# %%
#rename the index
fat_count.index.name='fat'
fat_count
# Out:
#      value_counts
# fat
# 0.0            30
# 1.0            30
# 2.0            13
# 3.0             3
# 5.0             1

# %%
df['calories'].unique()
# Out:
# array([ 70., 120.,  50., 110., 130.,  90., 100.,   0., 140., 160.,  80.])

# %%
df['fat'].unique()
df['name'].unique()
# Out:
# array(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats', 'Fruit & Fibre Dates',
#        'Fruitful Bran', 'Fruity Pebbles', 'Golden Crisp',
#        'Golden Grahams', 'Grape Nuts Flakes', 'Grape-Nuts',
#        'Great Grains Pecan', 'Honey Graham Ohs', 'Honey Nut Cheerios',
#        'Honey-comb', 'Just Right Crunchy  Nuggets',
#        'Just Right Fruit & Nut', 'Kix', 'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins', 'Mueslix Crispy Blend', 'Multi-Grain Cheerios',
# ...

# %%
df['mfr'].unique()
# Out:
# array(['N', 'Q', 'K', 'R', 'G', 'P', nan, 'A'], dtype=object)

# %%
df_grp1=df[['mfr','protein','calories']]
df_grp1=df_grp1.groupby(['mfr'],as_index=False).mean()
df_grp1
# Out:
#   mfr   protein    calories
# 0   A  4.000000  100.000000
# 1   G  2.318182  111.363636
# 2   K  2.652174  108.695652
# 3   N  2.833333   86.666667
# 4   P  2.375000  107.500000
# 5   Q  2.625000   95.000000
# 6   R  2.000000  103.333333

# %%
df_grp2=df_grp1=df[['mfr','type','calories']]
df_grp2=df_grp1.groupby(['type']).mean()
df_grp2
# Out:
#         calories
# type
# C     105.774648
# H     100.000000

# %%
grouped_pivot=df_grp1.pivot(index='mfr', columns='protein')
grouped_pivot
# Out:
#            calories                                                       \
# protein    2.000000    2.318182 2.375000 2.625000    2.652174   2.833333
# mfr
# A               NaN         NaN      NaN      NaN         NaN        NaN
# G               NaN  111.363636      NaN      NaN         NaN        NaN
# K               NaN         NaN      NaN      NaN  108.695652        NaN
# N               NaN         NaN      NaN      NaN         NaN  86.666667
# P               NaN         NaN    107.5      NaN         NaN        NaN
# Q               NaN         NaN      NaN     95.0         NaN        NaN
# R        103.333333         NaN      NaN      NaN         NaN        NaN
#
#
# protein 4.000000
# mfr
# A          100.0
# G            NaN
# K            NaN
# N            NaN
# P            NaN
# Q            NaN
# R            NaN

# %%
grouped_pivot=grouped_pivot.fillna(0)
grouped_pivot
# Out:
#            calories                                                       \
# protein    2.000000    2.318182 2.375000 2.625000    2.652174   2.833333
# mfr
# A          0.000000    0.000000      0.0      0.0    0.000000   0.000000
# G          0.000000  111.363636      0.0      0.0    0.000000   0.000000
# K          0.000000    0.000000      0.0      0.0  108.695652   0.000000
# N          0.000000    0.000000      0.0      0.0    0.000000  86.666667
# P          0.000000    0.000000    107.5      0.0    0.000000   0.000000
# Q          0.000000    0.000000      0.0     95.0    0.000000   0.000000
# R        103.333333    0.000000      0.0      0.0    0.000000   0.000000
#
#
# protein 4.000000
# mfr
# A          100.0
# G            0.0
# K            0.0
# N            0.0
# P            0.0
# Q            0.0
# R            0.0

# %%
grouped_anova

# %%
#HeatMap
plt.pcolor(grouped_pivot, cmap='Blues')
plt.colorbar()
plt.show()

# %%
fig, ax=plt.subplots()
im=ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels= grouped_pivot.columns.levels[1]
col_labels= grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1])+0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0])+0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels,minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate the label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
df.corr()
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000 -0.071648  0.419648  0.354206 -0.355982  0.256388
# protein  -0.071648  1.000000  0.143655 -0.039885  0.498610 -0.143227
# fat       0.419648  0.143655  1.000000  0.019642 -0.020329 -0.350141
# sodium    0.354206 -0.039885  0.019642  1.000000 -0.067327  0.362717
# fiber    -0.355982  0.498610 -0.020329 -0.067327  1.000000 -0.355039
# carbo     0.256388 -0.143227 -0.350141  0.362717 -0.355039  1.000000
# sugars    0.547685 -0.381669  0.229358  0.114690 -0.165885 -0.340435
# potass   -0.158991  0.532237  0.129051 -0.020719  0.906521 -0.359012
# vitamins  0.297116  0.013806 -0.022762  0.361351 -0.028791  0.259354
# shelf     0.033840  0.098137  0.216651 -0.059572  0.281135 -0.104785
# weight    0.758956  0.223383  0.221775  0.312261  0.231728  0.151341
# cups      0.051604 -0.278296 -0.224333  0.130735 -0.521842  0.357282
# rating   -0.712054  0.504070 -0.407215 -0.409548  0.600230  0.055804
#
# ...

# %%
<b>P-value</b>: 
<p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>

By convention, when the
<ul>
    <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
    <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
    <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
    <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
</ul>
# Out:
#   File "<ipython-input-75-408bbaa8d561>", line 1
#     <b>P-value</b>:
#     ^
# SyntaxError: invalid syntax

# %%
from scipy import stats

# %%
pearson_coef, p_value= stats.pearsonr(df['fat'],df['calories'])

# %%
pearson_coef
# Out:
# 0.41964835121610766

# %%
p_value
# Out:
# 0.00014520237178903197

# %%
grouped_test=df[['mfr','calories']].groupby(['mfr'])
grouped_test.head(1)
# Out:
#     mfr  calories
# 0     N      70.0
# 1     Q     120.0
# 2     K      70.0
# 4     R     110.0
# 5     G     110.0
# 9     P      90.0
# 27  NaN       0.0
# 43    A     100.0

# %%
grouped_test.get_group('N')['calories']
# Out:
# 0      70.0
# 20    100.0
# 63     80.0
# 64     90.0
# 65     90.0
# 68     90.0
# Name: calories, dtype: float64

# %%
#ANOVA
f_val, p_val=stats.f_oneway(grouped_test.get_group('N')['calories'], grouped_test.get_group('K')['calories'], grouped_test.get_group('Q')['calories'])

# %%
print("F-val is ", f_val, ",P-val is", p_val)
# Out:
# F-val is  2.768624148227548 ,P-val is 0.07691873049995761

# %%
f_val
# Out:
# 2.768624148227548
